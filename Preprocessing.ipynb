# %% [markdown]
# ## Preprocessing if needed

# %%
from parselmouth.praat import call, run_file
import pyloudnorm as pyln
import noisereduce as nr
import tensorflow as tf
import soundfile as sf
from glob import glob
import numpy as np
import parselmouth 
import librosa
import random
import re
import os

# %%
#path for temporary audio files
tmp_path = "D:\\Tonaufnahmen\\tmp\\tmp.wav"

#path of own praat scripts
praat_marksyllables = "C:\\Users\\Lea\\Praat\\plugin_VocalToolkit\\marksyllables_own.praat"
praat_changeformants = "C:\\Users\\Lea\\Praat\\plugin_VocalToolkit\\changeformants_own.praat"

#path of the parent folder of the audio files
#DATASET_PATH = "D:\\Tonaufnahmen\\NEUERHEBUNG_WS_ALT_Sorted_Preprocessed_min05_AllOverThree - Kopie"
DATASET_PATH = "D:\\Tonaufnahmen\\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\\"

#length of one audio segment in seconds
length = 10.0

# %% [markdown]
# ### Preprocessing functions

# %%
#https://superkogito.github.io/blog/2020/04/30/rms_normalization.html
def rms_normalize(sig, rms_level=0):
    r = 10**(rms_level / 10.0)
    a = np.sqrt( (len(sig) * r**2) / np.sum(sig**2) )
    y = sig * a
    return y

# %%
def peak_normalize(sig):
    y = sig / (max(sig)+0.2)
    return y

# %%
#https://medium.com/@poudelnipriyanka/audio-normalization-9dbcedfefcc0
def rms_normalize_pln(sig, rms_level=0):
    meter = pyln.Meter(16000)
    loudness = meter.integrated_loudness(sig)
    y = pyln.normalize.loudness(sig, loudness, rms_level)
    return y

# %%
#https://medium.com/@poudelnipriyanka/audio-normalization-9dbcedfefcc0
def peak_normalize_pln(sig, peak_level=0):
    y = pyln.normalize.peak(sig, peak_level)
    return y

# %%
def dc_offset(sig):
    y = sig - np.mean(sig)
    return y

# %%
def dc_offset_disturb(sig):
    disturbance = np.random.uniform(-0.1, 0.1)
    y = sig + disturbance
    return y

# %%
#normalize formants F1, F2 and F3
def normalize_formants(sig):
    path = tmp_path
    sf.write(path, sig, 16000, subtype='PCM_16')
    sound = parselmouth.Sound(path)
    new_sound = run_file(sound, praat_changeformants, 500, 1500, 25000, 0, 0, 5000, 'yes', 'yes', 'no')
    return new_sound[0].values.flatten()

# %%
#works better with Loudness/peak normalized audios
def get_new_tempo(audio, start, end):
    y, sr = librosa.load(new_path, sr=16000, res_type='soxr_vhq')
    sig = y[start:end]
    path = tmp_path
    sf.write(path, sig, 16000, subtype='PCM_16')
    sound = parselmouth.Sound(path)
    syllables = run_file(sound, praat_marksyllables, -25, 0.3, 2, 'yes', 'yes', capture_output=True)
    pattern = r"Articulation rate \(number of syllables \/ phonation time\): (\d+\.?\d*)"
    match = re.search(pattern, str(syllables))
    if match:
        articulation_rate = match.group(1)
        ar = float(articulation_rate)
        if (ar > 2 and ar < 6.5):
            #random_ar = random.uniform(2.5, 6)
            return ar/6.0
        else:
            print(syllables)
            return 1.0
    else:
        print("Pattern not found")

# %%
def make_new_tempo(sig, tempo):
    path = tmp_path
    sf.write(path, sig, 16000, subtype='PCM_16')
    sound = parselmouth.Sound(path)
    new_sound = call(sound, "Lengthen (overlap-add)", 75, 300, tempo)
    return new_sound.values.flatten()

# %%
def pitch_normalize(sig):
    new_pitch = 120
    #new_pitch = random.randint(90, 160)
    path = tmp_path
    sf.write(path, sig, 16000, subtype='PCM_16')
    sound = parselmouth.Sound(path)
    new_sound = call(sound, "Change gender", 80, 170, 1.0, new_pitch, 0.0, 1.0)
    return new_sound.values.flatten()

# %%
def pitch_normalize2(sig):
    new_pitch = 120
    new_std = 18
    path = tmp_path
    sf.write(path, sig, 16000, subtype='PCM_16')
    sound = parselmouth.Sound(path)
    
    pitch = call(sound, "To Pitch", 0.0, 80.0, 170.0)
    std_pitch = call(pitch, "Get standard deviation", 0.0, 0.0, 'Hertz', return_string=True)
    pattern = r"(\d+\.?\d*) Hz"
    match = re.search(pattern, str(std_pitch))
    if match:
        std_pitch_res = match.group(1)
        faktor = new_std/float(std_pitch_res)
    else:
        print(std_pitch)
        print("Pattern not found")
        return 0.0, 0  
    
    new_sound = call(sound, "Change gender", 80, 170, 1.0, new_pitch, faktor, 1.0)
    return new_sound.values.flatten()

# %%
def noise_reduction(sig):
    path = tmp_path
    sf.write(path, sig, 16000, subtype='PCM_16')
    sound = parselmouth.Sound(path)
    new_sound = call(sound, "Remove noise", 0, 0, 0.025, 80.0, 8000.0, 40.0, 'spectral-subtraction')
    return new_sound.values.flatten()

# %%
def noise_reduction2(sig):
    reduced_noise = nr.reduce_noise(y=sig, sr=16000)
    return reduced_noise

# %%
def preemphasis(sig):
    path = tmp_path
    sf.write(path, sig, 16000, subtype='PCM_16')
    sound = parselmouth.Sound(path)
    new_sound = call(sound, "Filter (pre-emphasis)...", 1300.807) #1300.807=0.6 #130.617=0.95
    return new_sound.values.flatten()

# %%
def cubic_root_compression(sig):
    #compressed_signal = np.sign(sig) * np.cbrt(np.abs(sig))
    compressed_signal = np.sign(sig) * (np.abs(sig) ** (2/3))
    return compressed_signal

# %% [markdown]
# ### Audio Files in the DATASET_PATH will be replaced by preprocessed ones!!!
#
# #### Output:
#
# This code snippet preprocesses the audio data by resampling each audio file to a sampling rate of 16kHz, converting them to mono, concatenating multiple audio files into one, and saving them back to their original directory structure. The resulting audio files are saved with a bit-depth of 16.
#
# Additionally, if there are multiple audio files within a single folder for a speaker, they are concatenated into a single audio file before preprocessing.
#
# Preprocessing steps can be applied before saving the audio files.

# %%
all_classes = glob(DATASET_PATH + '\\*', recursive = True)
all_speaker = []

# list of all classes
for dialect in all_classes:
    all_speaker = np.concatenate((all_speaker, glob(dialect + '\\*', recursive = True)), axis=None)
    
for path in all_speaker:
    audios = tf.io.gfile.glob(path + '\\*.wav')
    one_audio = []
    print(path)
    for audio in audios:
        # sample to 16kHz
        y, sr = librosa.load(audio, sr=16000, res_type='soxr_vhq')
        # to mono
        librosa.to_mono(y)
        # put all Audios of one speaker into one File
        one_audio.append(y)
        # remove original File
        os.remove(audio)
    if len(one_audio) < 1:
        print('Speaker empty')
    else:
        one_audio = np.concatenate(one_audio).ravel()
        if len(one_audio) < length*sr:
            print('Speaker to short!')
        else:
            #Preprocessing
            res_audio = []
            sr_length = int(length*16000)
            times = len(one_audio)//(sr_length)
            for i in range(0, times):
                ad = one_audio[i*sr_length:(i+1)*sr_length]
                #preprocessing step
                #tempo = get_new_tempo(audio, i*sr_length, (i+1)*sr_length)
                y = peak_normalize(ad)
                #y = normalize_formants(ad)
                #y1 = preemphasis(ad)
                #y = cubic_root_compression(y1)
                #y = ad
                res_audio.append(y)
                sf.write(path + '\\' + path.split('\\')[-1] + "_" + str(i) + '.wav', y, 16000, 'PCM_16')
            res_audio = np.concatenate(res_audio).ravel()
            # save as wav with a sampling-rate of 16kHz and bit-depth of 16
            #sf.write(path + '\\' + path.split('\\')[-1] + '.wav', res_audio, 16000, 'PCM_16')
# Out:
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\BRB1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\BRB2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\BRB3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\BRBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\BRBALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\BRBJUNG3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\OHV1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\OPR1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\OPRALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\OPRALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\OPRJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\P3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\P7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\P8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\P9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PR1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PRALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PRALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PRJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PRJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\PRJUNG3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\SDL1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\SDLALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Brandenburgisch\SDLJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\EM6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\EM7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\EMALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\EMJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\OG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\OG7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\OGALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\OGJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\WT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\WT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\WTALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Hochalemannisch\WTJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\DM1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\DM2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\DMALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\DMJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HRO4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HRO5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HROALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HROALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HROJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HROJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HST1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HST4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HSTALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HSTALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\HSTJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\MUER1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\MUERALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\MUERALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\MUERJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\MUERJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\RUEG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\RUEG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\RUEGALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\RUEGALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\RUEGJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\SN2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\SN4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\SNALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\SNALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\SNJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\VR1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\VR2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\VRALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\VRALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mecklenburgisch-Vorpommerisch\VRJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\RV2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\RV3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\RVALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\RVJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\TUT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\TUT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\TUTALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\TUTJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\VS3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\VS4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\VSALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\VSALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelalemannisch\VSJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\LH2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\LH3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\LHALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\LHALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\LHJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\LHJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\M10
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\M9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\MALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\MALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\MJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\PA2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\PA6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\PAALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\PAALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\PAJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\SR7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\SR9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\SRALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\SRALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\SRJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\SRJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\TS10
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\TS2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\TS6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\TSALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\TSALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\TSJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Mittelbairisch\TSJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\BETZ1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\BETZ2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\BETZALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\BETZALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\BETZJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\BETZJUNG2
# Speaker to short!
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\COC1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\COC2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\COCALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\COCJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\MT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\MT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\MT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\MTALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\MTALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\MTALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\MTJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TR1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TR2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRALT4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRSW2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRSW3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRSWALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRSWALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\TRSWJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\WIT10
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\WIT5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\WITALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\WITJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\WITJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Moselfraenkisch\WITJUNG3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Niederfraenkisch\KLEV2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Niederfraenkisch\KLEV3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Niederfraenkisch\KLEVALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Niederfraenkisch\OB2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Niederfraenkisch\OB6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Niederfraenkisch\OBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Niederfraenkisch\OBALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\AM2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\AM3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\AMALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\AMJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\AMJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\BT8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\BT9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\BTALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\BTJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\IN3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\IN5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\IN6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\INALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\INALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\INJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\WEN1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\WEN2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\WENALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\WENALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordbairisch\WENJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\FZ1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\FZ5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\FZ6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\FZALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\FZALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\FZJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\HR3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\HR4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\HRALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\HRALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\HRJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\KS1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\KS3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\KSALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordhessisch\KSJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CLP3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CLP6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CLPALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CLPALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CLPJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CUX2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CUXALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CUXALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CUXALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CUXALT4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CUXJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\CUXJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\FL1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\FL3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\FL9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\FLALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\FLALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\FLJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\HB1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\HB11
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\HBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\HBALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\HBALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\HBJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\LER4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\LER5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\LERALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\LERJUNG4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\NF13
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\NF8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\NFALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\NFJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\OL3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\OL5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\OLALT1_ungeeignet
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\OLALT2_ungeeignet
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\OLALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\OLJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\PI11
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\PIALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\PIJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\RD5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\RD7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\RDALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\RDJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\RDJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SE1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SE2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SE5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SEALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SEALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SEJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SEJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SL10
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SL9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SLALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\SLJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\WHV6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\WHV8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\WHVALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\WHVALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Nordniederdeutsch\WHVJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\DD4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\DD6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\DDALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\DDJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\DDJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\EE1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\EE2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\EEALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\EEALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\EEALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\EEJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\FG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\FGALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\FGJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\FGJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\Z2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\Z9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\ZALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Obersaechsisch\ZJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\GF3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\GF4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\GFALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\GFJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HBS10
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HBS9
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HBSALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HBSALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HBSJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HBSJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HBSJUNG3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HI3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HI4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HIALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HIALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HIALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\HIJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\NOM2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\NOM3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\NOMALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\NOMALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\NOMALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfaelisch\NOMJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\AN3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\AN4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\AN5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ANALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ANALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ANJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\BA1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\BA3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\BAALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\BAJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\BAJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ER
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ER4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ER6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ER7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ERALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ERALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\ERJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HBN1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HBN2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HBNALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HBNALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HBNJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HO1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HO2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HOALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\HOJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\SW1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\SW2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\SWALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\SWJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\TBB3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\TBB5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\TBBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\TBBALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\TBBJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\WUE1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\WUE13
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\WUE8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\WUEALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ostfraenkisch\WUEJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FD1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FD2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FD3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FD4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FD6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FD7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FDALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FDALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FDALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FDJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FDJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Osthessisch\FDJUNG5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\DA1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\DA5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\DAALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\DAALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\DAJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\ERB1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\ERB2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\ERB3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\ERBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\ERBJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HASS2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HASS4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HASS5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HASS6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HASSALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HASSALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HASSJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HD1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HD7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HDALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\HDJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\KL3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\KL7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\KLALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\KLALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\KLALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\KLJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\LAUTER1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\LAUTER2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\LAUTER3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\LAUTERALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\LAUTERJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\LAUTERJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\OPP1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\OPP2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\OPPALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\OPPJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\WO1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\WO2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\WOALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Rheinfraenkisch\WOJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\AC2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\AC3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\AC4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\ACALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\ACALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\ACJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\BM2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\BM3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\BMALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\BMALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\BMJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\DN1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\DN2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\DNALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\DNJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\GL3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\GL5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\GLALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\GLALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\GLJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\K15
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\K16
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\KALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\KALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\KJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\KJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\KJUNG3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\SU1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\SU4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\SUALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Ripuarisch\SUJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\A3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\A5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\AA1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\AA2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\AAALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\AAJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\AALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\AALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\AALT4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BB1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BB3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BBALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BBJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BC3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BC4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BCALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BCJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BCJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BL2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BL3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BL5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BLALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BLALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\BLJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\CW1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\CW2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\CWALT
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\CWJUNG3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\CWJUNG4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\DLG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\DLG6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\DLGALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\DLGALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\DLGALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\DLGJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\DLGJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\KF1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\KF2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\KFALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\KFALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\KFJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\UL1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\UL3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\ULALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\ULJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\ULJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\WN2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\WN3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\WNALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\WNALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Schwaebisch\WNJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EF1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EF2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EF3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EFALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EFALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EFJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EFJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EIC1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EIC4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EICALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EICALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\EICJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\GTH1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\GTH5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\GTHALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\GTHALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\GTHJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\KYF2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\KYF5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\KYFALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Thueringisch\KYFJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\BOR2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\BOR8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\BORALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\BORALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\BORJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\COE1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\COE3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\COEALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\COEALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\COEJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\GT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\GT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\GTALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\GTALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\GTJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\GTJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HA3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HA4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAM1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAM5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAMALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAMALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAMALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HAMJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSK14
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSK15
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSK18
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSK19
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSKALT4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSKALT5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSKALT6
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSKALT7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSKJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSKJUNG3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\HSKJUNG5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\LIP5
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\LIP8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\LIPALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\LIPALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\LIPJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\OE7
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\OE8
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\OEALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\OEALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\OEALT4
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Westfaelisch\OEJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\BUD1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\BUD2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\BUD3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\BUDALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\BUDALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\BUDJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\FB1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\FB3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\FBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\FBALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\FBALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\FBJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\FBJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\GI11
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\GI12
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\GIALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\GIALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\GIJUNG
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\HGALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\LDK2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\LDK3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\LDKALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\LDKALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\LDKALT3
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\LDKJUNG1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\LDKJUNG2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\VB1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\VB2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\VBALT1
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\VBALT2
# D:\Tonaufnahmen\NEUERHEBUNG_WS_ALL_Sorted_Preprocessed_min05_AllOverThree - Kopie\Zentralhessisch\VBJUNG1
